# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Generate some sample data for training
# Replace this with your actual mouse or timeseries data
 # Example data with 1000 samples and 10 features

# Scale the data for better training performance

X = df_major.drop(['userId_', 'userType_'], axis=1)
print(X.shape)
# X.fillna(0, inplace=True)
X.dropna(inplace=True)
scaler=StandardScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)
# X=X.sample(frac=0.2)
# Split into training and validation sets
X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
X_train, X_test = train_test_split(X_train, test_size=0.1, random_state=42)
print(X_train.shape)
# Autoencoder Architecture
input_dim = X_train.shape[1]  # Input dimensions, e.g., 10 features
encoding_dim = 3  # Dimension of the latent space (compressed data)
print(np.isnan(X_train).any())
print(np.isinf(X_train).any())
# Out:
# (64743, 6)
# (33171, 6)
# speed_mean           False
# speed_std            False
# acceleration_mean    False
# acceleration_std     False
# angle_diff_mean      False
# angle_diff_std       False
# dtype: bool
# speed_mean           False
# speed_std            False
# acceleration_mean    False
# acceleration_std     False
# angle_diff_mean      False
# angle_diff_std       False
# dtype: bool
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
pip install --upgrade tensorflow keras
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.3/601.3 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.4 MB/s eta 0:00:000:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 20.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: keras
#     Found existing installation: keras 3.3.3
#     Uninstalling keras-3.3.3:
#       Successfully uninstalled keras-3.3.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.1
#     Uninstalling tensorflow-2.16.1:
# ...

# %%
import matplotlib.pyplot as plt
# Plot training & validation loss values
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.ylabel('Loss (Mean Squared Error)')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
# Use your trained autoencoder to predict (reconstruct) the data
X_train_reconstructed = autoencoder.predict(X_train)
X_val_reconstructed = autoencoder.predict(X_val)
X_test_reconstructed = autoencoder.predict(X_test)




# Calculate the reconstruction error for each sample
reconstruction_error_train = np.mean(np.square(X_train - X_train_reconstructed), axis=1)
reconstruction_error_val = np.mean(np.square(X_val - X_val_reconstructed), axis=1)
reconstruction_error_test = np.mean(np.square(X_test - X_test_reconstructed), axis=1)




y = df_minor.drop(['userId_', 'userType_'], axis=1)
print(y.shape)
# X.fillna(0, inplace=True)
y.dropna(inplace=True)
scaler=StandardScaler()
y_scaled = scaler.fit_transform(y)
y = pd.DataFrame(y_scaled, columns=y.columns)
y_reconstructed = autoencoder.predict(y)
reconstruction_error_y = np.mean(np.square(y - y_reconstructed), axis=1)


print("AA",reconstruction_error_train)
print("BB",reconstruction_error_val)
print("CC",reconstruction_error_test)
print("DD",reconstruction_error_y)

# Set a threshold for detecting anomalies`
# You can use a quantile (e.g., 95th percentile) of the training reconstruction errors to set the threshold
# threshold = np.percentile(reconstruction_error_train, 95)

# print(f"Threshold for anomaly detection: {threshold}")

# # Detect anomalies in validation data
# anomalies_val = reconstruction_error_val > threshold

# # Convert the result into a DataFrame for better readability
# anomalies_df = pd.DataFrame({
#     'Reconstruction Error': reconstruction_error_val,
#     'Anomaly': anomalies_val
# })

# # Output: Display the anomalies
# print(anomalies_df.head(10))  # Display first 10 validation samples
# print(f"Number of anomalies detected in validation set: {np.sum(anomalies_val)}"
# Out:
# 1037/1037 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# (2596, 6)
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# AA 21071    0.003369
# 39903    0.001438
# 25392    0.002893
# 6250     0.051793
# 8201     0.005670
#            ...
# 40349    0.010767
# 3456     0.003930
# 36638    0.011545
# 3284     0.000538
# 28321    0.001934
# Length: 33171, dtype: float64
# BB 35540    0.010645
# 13924    0.001860
# 21802    0.008811
# 10915    0.002090
# 28508    0.086257
#            ...
# 17222    0.001329
# 7002     0.003863
# 8801     0.001332
# 38192    0.042104
# 19780    0.002546
# Length: 9215, dtype: float64
# CC 42437    0.000930
# 33615    0.009677
# 16083    0.006783
# 39486    0.007075
# 29406    0.004719
#            ...
# 3474     0.003630
# 33889    0.005535
# 30276    0.005797
# 37000    0.001783
# 12875    0.005707
# Length: 3686, dtype: float64
# DD 0       0.327614
# 1       0.493738
# 2       0.663550
# ...

# %%
import matplotlib.pyplot as plt

# Plot the reconstruction errors for different sets
plt.figure(figsize=(10, 6))

# Plot training reconstruction error
plt.hist(reconstruction_error_train, bins=50, color='blue', alpha=0.6, label='Train Reconstruction Error')

# Plot validation reconstruction error
plt.hist(reconstruction_error_val, bins=50, color='green', alpha=0.6, label='Validation Reconstruction Error')

# Plot test reconstruction error
plt.hist(reconstruction_error_test, bins=50, color='orange', alpha=0.6, label='Test Reconstruction Error')

# Plot y reconstruction error
plt.hist(reconstruction_error_y, bins=50, color='red', alpha=0.6, label='Y Reconstruction Error')

# Add labels and title
plt.title('Reconstruction Error Distribution Across Train, Validation, Test, and Y Sets')
plt.xlabel('Reconstruction Error')
plt.ylabel('Frequency')
plt.xlim(0,10)
# Add legend to differentiate the curves
plt.legend(loc='upper right')

# Show the plot
plt.show()
